# %%
# shape의 이해
import numpy as np

# scores는 몇 행, 몇 열인가.
scores = np.array([
#     1열   2열   3열 
# 1행[0.9, 0.8, 1.0],
# 2행[0.4, 0.7, 0.9],
# 3행[0.8, 0.9, 0.8]
])

#3행 3열

# 이 모양을 코드로 확인하는 것이 shape
print(scores.shape)
# Out:
# (0,)
